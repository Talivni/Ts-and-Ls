# %%
import numpy as np
import pandas as pd 
import re
import matplotlib.pyplot as plt
import correctAnalysis as ca

data = pd.read_csv("C:\\Users\\talil\\OneDrive\\Documents\\GitHub\\Ts-and-Ls\\ver1.csv")
data.head(10)
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"Australia/...
# 2                                     29-06-20 14:33
# 3                                      01-07-20 7:57
# 4                                      03-07-20 9:33
# 5                                     30-06-20 18:01
# 6                                      01-07-20 6:58
# 7                                     02-07-20 23:21
# 8                                     02-07-20 23:37
# 9                                     11-07-20 20:55
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"Australia/Ca...  {"ImportId":"status"}
# 2                                     29-06-20 14:34             IP Address
# ...

# %% [markdown]
# **<span style="color:blue"> Clean data: </span>**
#
# 1) Only finished attempts
#
# 2) Only real attempts (not preview)

# %%
data = data.query("Finished == 'TRUE' & Status != 'Survey Preview'")
data
# Out:
#        StartDate        EndDate      Status       IPAddress Progress  \
# 3  01-07-20 7:57  01-07-20 8:35  IP Address  121.221.135.96      100
# 4  03-07-20 9:33  03-07-20 9:53  IP Address   175.33.242.38      100
#
#   Duration (in seconds) Finished   RecordedDate         ResponseId  \
# 3                  2309     TRUE  01-07-20 8:35  R_2RWGqp7NAjjoIhQ
# 4                  1179     TRUE  03-07-20 9:53  R_ZwY9chonUDnBPrP
#
#   RecipientLastName  ... explanation_time_Last Click  \
# 3               NaN  ...                         NaN
# 4               NaN  ...                         NaN
#
#   explanation_time_Page Submit explanation_time_Click Count  \
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   GE_Comp_Assi_time_First Click GE_Comp_Assi_time_Last Click  \
# 3                       186.214                      455.163
# 4                           NaN                          NaN
#
# ...

# %% [markdown]
# **<span style="color:blue"> Checking Success rate: </span>**
#
# **Format:** Mturk_ID (cohort).
#
# Provides the answer of a participant to the letters [C, E, F, L, M, M, O, T] on wach game (1-10), and whether the answer correct or not.

# %%
ca.correct_rate(data)
# Out:
# 44690845  ( 4 )
# 1 :  [0, 0, 0, 2, 2, 3, 0, 1] False
# 2 :  [0, 0, 0, 0, 0, 8, 0, 0] False
# 3 :  [2, 2, 2, 0, 0, 0, 2, 0] False
# 4 :  [0, 0, 0, 2, 0, 4, 1, 2] False
# 5 :  [2, 1, 1, 0, 0, 0, 0, 0] False
# 6 :  [0, 0, 0, 0, 0, 0, 6, 0] False
# 7 :  [0, 1, 1, 1, 2, 1, 2, 1] True
# 8 :  [0, 0, 0, 8, 0, 0, 0, 0] False
# 9 :  [0, 0, 0, 0, 1, 0, 0, 0] False
# 10 :  [0, 1, 0, 2, 0, 3, 0, 0] False
# 36330163  ( 3 )
# 1 :  [0, 0, 0, 1, 2, 2, 0, 1] False
# 2 :  [0, 4, 1, 0, 0, 0, 0, 1] False
# 3 :  [2, 2, 3, 0, 0, 0, 2, 0] True
# 4 :  [0, 0, 0, 1, 0, 4, 1, 1] False
# 5 :  [1, 0, 1, 0, 0, 0, 2, 1] False
# 6 :  [0, 2, 0, 0, 0, 2, 1, 0] False
# 7 :  [0, 0, 1, 1, 1, 1, 2, 0] False
# 8 :  [1, 2, 1, 0, 0, 0, 0, 0] False
# 9 :  [0, 1, 0, 0, 0, 1, 2, 0] False
# 10 :  [0, 1, 0, 0, 2, 3, 0, 1] False
