# %%
import numpy as np
import pandas as pd 
import re
import matplotlib.pyplot as plt

data = pd.read_csv("C:\\Users\\talil\\Downloads\\Ts_and_Ls\\ver1.csv")
data.head(10)
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"Australia/...
# 2                                2020-06-29 14:33:27
# 3                                2020-06-30 09:59:31
# 4                                2020-06-30 10:44:16
# 5                                2020-06-30 19:11:05
# 6                                2020-07-01 07:57:22
# 7                                2020-07-03 09:33:58
# 8                                2020-06-30 18:01:46
# 9                                2020-07-01 06:58:58
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"Australia/Ca...  {"ImportId":"status"}
# 2                                2020-06-29 14:34:09             IP Address
# 3                                2020-06-30 10:17:22             IP Address
# 4                                2020-06-30 10:58:30             IP Address
# 5                                2020-06-30 19:14:55             IP Address
# 6                                2020-07-01 08:35:51             IP Address
# 7                                2020-07-03 09:53:37             IP Address
# 8                                2020-06-30 18:02:23             IP Address
# 9                                2020-07-01 07:00:12             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
# 2            124.148.149.50                        5                       42
# 3            124.148.149.50                      100                     1071
# 4            124.148.149.50                      100                      854
# 5            124.148.149.50                      100                      230
# 6            121.221.135.96                      100                     2309
# 7             175.33.242.38                      100                     1179
# 8            124.148.149.50                        1                       37
# 9             175.33.242.38                       78                       74
#
#                   Finished                                       RecordedDate  \
# 0                 Finished                                      Recorded Date
# 1  {"ImportId":"finished"}  {"ImportId":"recordedDate","timeZone":"Austral...
# 2                    False                                2020-06-29 14:39:45
# 3                     True                                2020-06-30 10:17:23
# 4                     True                                2020-06-30 10:58:31
# 5                     True                                2020-06-30 19:14:56
# 6                     True                                2020-07-01 08:35:51
# 7                     True                                2020-07-03 09:53:38
# 8                    False                                2020-07-07 18:02:28
# 9                    False                                2020-07-08 07:00:16
#
#                  ResponseId                 RecipientLastName  ...  \
# 0               Response ID               Recipient Last Name  ...
# 1  {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 2         R_XiFLCUjY1aLTDYl                               NaN  ...
# 3         R_1gGcQFSfcrT4Qoe                               NaN  ...
# 4         R_XYh24oEsyczQ7jH                               NaN  ...
# 5         R_WugZ25PGENcF6cp                               NaN  ...
# 6         R_2RWGqp7NAjjoIhQ                               NaN  ...
# 7         R_ZwY9chonUDnBPrP                               NaN  ...
# 8         R_3GxJCleSyh8l8VG                               NaN  ...
# 9         R_1M5JvjSnx29chbB                               NaN  ...
#
#         explanation_time_Click Count      GE_Comp_Assi_time_First Click  \
# 0               Timing - Click Count               Timing - First Click
# 1  {"ImportId":"QID978_CLICK_COUNT"}  {"ImportId":"QID801_FIRST_CLICK"}
# 2                                NaN                                NaN
# 3                                NaN                                  0
# 4                                NaN                                NaN
# 5                                NaN                                NaN
# 6                                NaN                            186.214
# 7                                NaN                                NaN
# 8                                NaN                                NaN
# 9                                NaN                                NaN
#
#        GE_Comp_Assi_time_Last Click      GE_Comp_Assi_time_Page Submit  \
# 0               Timing - Last Click               Timing - Page Submit
# 1  {"ImportId":"QID801_LAST_CLICK"}  {"ImportId":"QID801_PAGE_SUBMIT"}
# 2                               NaN                                NaN
# 3                                 0                             75.881
# 4                               NaN                                NaN
# 5                               NaN                                NaN
# 6                           455.163                             456.18
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
#
#        GE_Comp_Assi_time_Click Count                 training_counter  \
# 0               Timing - Click Count                 training_counter
# 1  {"ImportId":"QID801_CLICK_COUNT"}  {"ImportId":"training_counter"}
# 2                                NaN                                1
# 3                                  0                                5
# 4                                NaN                                5
# 5                                NaN                                5
# 6                                  4                                5
# 7                                NaN                                5
# 8                                NaN                              NaN
# 9                                NaN                                1
#
#                   game_counter                 mTurk  \
# 0                 game_counter                 mTurk
# 1  {"ImportId":"game_counter"}  {"ImportId":"mTurk"}
# 2                            1                   NaN
# 3                           11              05406616
# 4                           11             022453980
# 5                           11             019039243
# 6                           11             044690845
# 7                           11             036330163
# 8                          NaN                   NaN
# 9                            1             058487618
#
#                        gender_9_TEXT - Parent Topics  \
# 0                      gender_9_TEXT - Parent Topics
# 1  {"ImportId":"QID146_9_TEXT_6f8aa9c44dad416695e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                               gender_9_TEXT - Topics
# 0                             gender_9_TEXT - Topics
# 1  {"ImportId":"QID146_9_TEXT_6f8aa9c44dad416695e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 595 columns]

# %% [markdown]
# **<span style="color:blue"> Clean data: </span>**
#
# 1) Only finished attempts
#
# 2) Only real attempts (not preview)

# %%
data = data.query("Finished == 'True' & Status != 'Survey Preview'")
data
# Out:
#              StartDate              EndDate      Status       IPAddress  \
# 3  2020-06-30 09:59:31  2020-06-30 10:17:22  IP Address  124.148.149.50
# 4  2020-06-30 10:44:16  2020-06-30 10:58:30  IP Address  124.148.149.50
# 5  2020-06-30 19:11:05  2020-06-30 19:14:55  IP Address  124.148.149.50
# 6  2020-07-01 07:57:22  2020-07-01 08:35:51  IP Address  121.221.135.96
# 7  2020-07-03 09:33:58  2020-07-03 09:53:37  IP Address   175.33.242.38
#
#   Progress Duration (in seconds) Finished         RecordedDate  \
# 3      100                  1071     True  2020-06-30 10:17:23
# 4      100                   854     True  2020-06-30 10:58:31
# 5      100                   230     True  2020-06-30 19:14:56
# 6      100                  2309     True  2020-07-01 08:35:51
# 7      100                  1179     True  2020-07-03 09:53:38
#
#           ResponseId RecipientLastName  ... explanation_time_Click Count  \
# 3  R_1gGcQFSfcrT4Qoe               NaN  ...                          NaN
# 4  R_XYh24oEsyczQ7jH               NaN  ...                          NaN
# 5  R_WugZ25PGENcF6cp               NaN  ...                          NaN
# 6  R_2RWGqp7NAjjoIhQ               NaN  ...                          NaN
# 7  R_ZwY9chonUDnBPrP               NaN  ...                          NaN
#
#   GE_Comp_Assi_time_First Click GE_Comp_Assi_time_Last Click  \
# 3                             0                            0
# 4                           NaN                          NaN
# 5                           NaN                          NaN
# 6                       186.214                      455.163
# 7                           NaN                          NaN
#
#   GE_Comp_Assi_time_Page Submit GE_Comp_Assi_time_Click Count  \
# 3                        75.881                             0
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 6                        456.18                             4
# 7                           NaN                           NaN
#
#   training_counter game_counter      mTurk gender_9_TEXT - Parent Topics  \
# 3                5           11   05406616                           NaN
# 4                5           11  022453980                           NaN
# 5                5           11  019039243                           NaN
# 6                5           11  044690845                           NaN
# 7                5           11  036330163                           NaN
#
#   gender_9_TEXT - Topics
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
#
# [5 rows x 595 columns]

# %%
for x in data.mTurk : print(x[1])
# Out:
# 5
# 2
# 1
# 4
# 3

# %%
for i in range(len(data)):
    row = data.iloc[i, : ]
    print(row['mTurk'][1])
# Out:
# 5
# 2
# 1
# 4
# 3
